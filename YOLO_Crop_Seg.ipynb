# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install Ultralytics
# !pip install -U ultralytics

# %%
# Training model YOLO

from ultralytics import YOLO

# Load model YOLO
model = YOLO('/content/drive/MyDrive/yolo/yolo11m-seg.pt')

# Start training
model.train(
    data='/content/drive/MyDrive/yolo/crop_map.v5i.yolov11/data.yaml',
    epochs=100,
    imgsz=640,
    batch=8,
    project='/content/drive/MyDrive/yolo/crop_map.v5i.yolov11/hasil_run_no_aug',
    name='yolo11m_paddy_seg',
    device=0,
    # select the augmentation you want to use
    flipud=0.5,      # objects do not have top-down orientation
    degrees=45,      # objects can face any direction
    hsv_h=0.0,       # maintain the color of vegetation

    # Stability training
    optimizer="AdamW",
    lr0=0.001,
    patience=20,
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
